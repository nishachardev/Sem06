# %% [markdown]
# ### Run Apriori algorithm to find frequent itemsets and association rules

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Groceries_dataset.csv')

# %%
df
# Out:
#        Member_number        Date        itemDescription
# 0               1808  21-07-2015         tropical fruit
# 1               2552  05-01-2015             whole milk
# 2               2300  19-09-2015              pip fruit
# 3               1187  12-12-2015       other vegetables
# 4               3037  01-02-2015             whole milk
# ...              ...         ...                    ...
# 38760           4471  08-10-2014          sliced cheese
# 38761           2022  23-02-2014                  candy
# 38762           1097  16-04-2014               cake bar
# 38763           1510  03-12-2014  fruit/vegetable juice
# 38764           1521  26-12-2014               cat food
#
# [38765 rows x 3 columns]

# %% [markdown]
# ### Group items that are purchased by same member on same date (same transaction)

# %%
df['single-transaction'] = df['Member_number'].astype(str) + '_' + df['Date'].astype(str)

# %%
df.head()
# Out:
#    Member_number        Date   itemDescription single-transaction
# 0           1808  21-07-2015    tropical fruit    1808_21-07-2015
# 1           2552  05-01-2015        whole milk    2552_05-01-2015
# 2           2300  19-09-2015         pip fruit    2300_19-09-2015
# 3           1187  12-12-2015  other vegetables    1187_12-12-2015
# 4           3037  01-02-2015        whole milk    3037_01-02-2015

# %%
df2 = pd.crosstab(df['single-transaction'], df['itemDescription'])

# %%
df2.head()
# Out:
# itemDescription     Instant food products  UHT-milk  abrasive cleaner  \
# single-transaction
# 1000_15-03-2015                         0         0                 0
# 1000_24-06-2014                         0         0                 0
# 1000_24-07-2015                         0         0                 0
# 1000_25-11-2015                         0         0                 0
# 1000_27-05-2015                         0         0                 0
#
# itemDescription     artif. sweetener  baby cosmetics  bags  baking powder  \
# single-transaction
# 1000_15-03-2015                    0               0     0              0
# 1000_24-06-2014                    0               0     0              0
# 1000_24-07-2015                    0               0     0              0
# 1000_25-11-2015                    0               0     0              0
# 1000_27-05-2015                    0               0     0              0
#
# itemDescription     bathroom cleaner  beef  berries  ...  turkey  vinegar  \
# single-transaction                                   ...
# 1000_15-03-2015                    0     0        0  ...       0        0
# 1000_24-06-2014                    0     0        0  ...       0        0
# 1000_24-07-2015                    0     0        0  ...       0        0
# 1000_25-11-2015                    0     0        0  ...       0        0
# 1000_27-05-2015                    0     0        0  ...       0        0
#
# itemDescription     waffles  whipped/sour cream  whisky  white bread  \
# single-transaction
# 1000_15-03-2015           0                   0       0            0
# 1000_24-06-2014           0                   0       0            0
# 1000_24-07-2015           0                   0       0            0
# 1000_25-11-2015           0                   0       0            0
# 1000_27-05-2015           0                   0       0            0
#
# itemDescription     white wine  whole milk  yogurt  zwieback
# single-transaction
# 1000_15-03-2015              0           1       1         0
# 1000_24-06-2014              0           1       0         0
# 1000_24-07-2015              0           0       0         0
# 1000_25-11-2015              0           0       0         0
# 1000_27-05-2015              0           0       0         0
#
# [5 rows x 167 columns]

# %% [markdown]
# ### Encoding dataset into binary values

# %%
def encode(item_freq):
    res = False
    if (item_freq > 0):
        res = True
    return res

# %%
df2 = df2.applymap(encode)

# %%
df2.head()
# Out:
# itemDescription     Instant food products  UHT-milk  abrasive cleaner  \
# single-transaction
# 1000_15-03-2015                     False     False             False
# 1000_24-06-2014                     False     False             False
# 1000_24-07-2015                     False     False             False
# 1000_25-11-2015                     False     False             False
# 1000_27-05-2015                     False     False             False
#
# itemDescription     artif. sweetener  baby cosmetics   bags  baking powder  \
# single-transaction
# 1000_15-03-2015                False           False  False          False
# 1000_24-06-2014                False           False  False          False
# 1000_24-07-2015                False           False  False          False
# 1000_25-11-2015                False           False  False          False
# 1000_27-05-2015                False           False  False          False
#
# itemDescription     bathroom cleaner   beef  berries  ...  turkey  vinegar  \
# single-transaction                                    ...
# 1000_15-03-2015                False  False    False  ...   False    False
# 1000_24-06-2014                False  False    False  ...   False    False
# 1000_24-07-2015                False  False    False  ...   False    False
# 1000_25-11-2015                False  False    False  ...   False    False
# 1000_27-05-2015                False  False    False  ...   False    False
#
# itemDescription     waffles  whipped/sour cream  whisky  white bread  \
# single-transaction
# 1000_15-03-2015       False               False   False        False
# 1000_24-06-2014       False               False   False        False
# 1000_24-07-2015       False               False   False        False
# 1000_25-11-2015       False               False   False        False
# 1000_27-05-2015       False               False   False        False
#
# itemDescription     white wine  whole milk  yogurt  zwieback
# single-transaction
# 1000_15-03-2015          False        True    True     False
# 1000_24-06-2014          False        True   False     False
# 1000_24-07-2015          False       False   False     False
# 1000_25-11-2015          False       False   False     False
# 1000_27-05-2015          False       False   False     False
#
# [5 rows x 167 columns]

# %% [markdown]
# ### Finding frequent itemsets from transactions

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
freq_itemsets = apriori(df2, min_support=0.001, use_colnames=True)

# %%
freq_itemsets
# Out:
#       support                           itemsets
# 0    0.004010            (Instant food products)
# 1    0.021386                         (UHT-milk)
# 2    0.001470                 (abrasive cleaner)
# 3    0.001938                 (artif. sweetener)
# 4    0.008087                    (baking powder)
# ..        ...                                ...
# 745  0.001136  (sausage, rolls/buns, whole milk)
# 746  0.001002     (rolls/buns, soda, whole milk)
# 747  0.001337   (yogurt, rolls/buns, whole milk)
# 748  0.001069        (sausage, soda, whole milk)
# 749  0.001470      (yogurt, sausage, whole milk)
#
# [750 rows x 2 columns]

# %%
rules = association_rules(freq_itemsets, metric='confidence', min_threshold=0.15)

# %%
rules.sort_values(['support', 'confidence'], ascending=False)
# Out:
#              antecedents   consequents  antecedent support  \
# 0         (bottled beer)  (whole milk)            0.045312
# 3                  (ham)  (whole milk)            0.017109
# 4  (semi-finished bread)  (whole milk)            0.009490
# 8      (yogurt, sausage)  (whole milk)            0.005748
# 9  (sausage, whole milk)      (yogurt)            0.008955
# 1            (detergent)  (whole milk)            0.008621
# 6   (yogurt, rolls/buns)  (whole milk)            0.007819
# 5  (sausage, rolls/buns)  (whole milk)            0.005347
# 7        (sausage, soda)  (whole milk)            0.005948
# 2          (frozen fish)  (whole milk)            0.006817
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.157923  0.007151    0.157817  0.999330 -0.000005    0.999874
# 3            0.157923  0.002740    0.160156  1.014142  0.000038    1.002659
# 4            0.157923  0.001671    0.176056  1.114825  0.000172    1.022008
# 8            0.157923  0.001470    0.255814  1.619866  0.000563    1.131541
# 9            0.085879  0.001470    0.164179  1.911760  0.000701    1.093681
# 1            0.157923  0.001403    0.162791  1.030824  0.000042    1.005814
# 6            0.157923  0.001337    0.170940  1.082428  0.000102    1.015701
# 5            0.157923  0.001136    0.212500  1.345594  0.000292    1.069304
# 7            0.157923  0.001069    0.179775  1.138374  0.000130    1.026642
# 2            0.157923  0.001069    0.156863  0.993287 -0.000007    0.998743
