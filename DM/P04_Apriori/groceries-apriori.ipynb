# %% [markdown]
# ### Run Apriori algorithm to find frequent itemsets and association rules

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('groceries.csv')

# %%
df
# Out:
#                                                  Items
# 0    citrus fruit,semi-finished bread,margarine,rea...
# 1                         tropical fruit,yogurt,coffee
# 2                                           whole milk
# 3          pip fruit,yogurt,cream cheese ,meat spreads
# 4    other vegetables,whole milk,condensed milk,lon...
# ..                                                 ...
# 695       pork,UHT-milk,bottled water,soda,canned beer
# 696  other vegetables,curd,yogurt,curd cheese,marga...
# 697  rolls/buns,soda,fruit/vegetable juice,canned b...
# 698  frankfurter,pip fruit,whole milk,rolls/buns,ro...
# 699   yogurt,hygiene articles,newspapers,shopping bags
#
# [700 rows x 1 columns]

# %% [markdown]
# ### Split the items into array of items

# %%
data = list(df['Items'].str.split(','))

# %%
data[:5]
# Out:
# [['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups'],
#  ['tropical fruit', 'yogurt', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product']]

# %% [markdown]
# ### Encoding items into one hot encoding (true / false values)

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
data = te.fit_transform(data)
data
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ...,  True, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ...,  True, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df = pd.DataFrame(data, columns=te.columns_)

# %%
df
# Out:
#      Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                    False     False             False             False
# 1                    False     False             False             False
# 2                    False     False             False             False
# 3                    False     False             False             False
# 4                    False     False             False             False
# ..                     ...       ...               ...               ...
# 695                  False      True             False             False
# 696                  False     False             False             False
# 697                  False     False             False             False
# 698                  False     False             False             False
# 699                  False     False             False             False
#
#      baby cosmetics  baking powder  bathroom cleaner   beef  berries  \
# 0             False          False             False  False    False
# 1             False          False             False  False    False
# 2             False          False             False  False    False
# 3             False          False             False  False    False
# 4             False          False             False  False    False
# ..              ...            ...               ...    ...      ...
# 695           False          False             False  False    False
# 696           False          False             False  False    False
# 697           False          False             False  False    False
# 698           False          False             False  False    False
# 699           False          False             False  False    False
#
#      beverages  ...  tropical fruit  turkey  vinegar  waffles  \
# 0        False  ...           False   False    False    False
# 1        False  ...            True   False    False    False
# 2        False  ...           False   False    False    False
# 3        False  ...           False   False    False    False
# 4        False  ...           False   False    False    False
# ..         ...  ...             ...     ...      ...      ...
# 695      False  ...           False   False    False    False
# 696      False  ...           False   False    False    False
# 697      False  ...           False   False    False    False
# 698      False  ...           False   False    False    False
# 699      False  ...           False   False    False    False
#
#      whipped/sour cream  white bread  white wine  whole milk  yogurt  zwieback
# 0                 False        False       False       False   False     False
# 1                 False        False       False       False    True     False
# 2                 False        False       False        True   False     False
# 3                 False        False       False       False    True     False
# 4                 False        False       False        True   False     False
# ..                  ...          ...         ...         ...     ...       ...
# 695               False        False       False       False   False     False
# 696               False        False       False       False    True     False
# 697               False        False        True       False   False     False
# 698               False        False       False        True   False     False
# 699               False        False       False       False    True     False
#
# [700 rows x 152 columns]

# %% [markdown]
# ### Finding frequent itemsets and association rules

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
freq_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# %%
freq_itemsets
# Out:
#       support                                       itemsets
# 0    0.020000                                     (UHT-milk)
# 1    0.011429                                (baking powder)
# 2    0.060000                                         (beef)
# 3    0.040000                                      (berries)
# 4    0.031429                                    (beverages)
# ..        ...                                            ...
# 309  0.012857  (root vegetables, tropical fruit, whole milk)
# 310  0.010000          (root vegetables, whole milk, yogurt)
# 311  0.011429                  (whole milk, sausage, yogurt)
# 312  0.011429                     (soda, whole milk, yogurt)
# 313  0.012857           (tropical fruit, whole milk, yogurt)
#
# [314 rows x 2 columns]

# %%
rules = association_rules(freq_itemsets, metric='confidence', min_threshold=0.6)

# %%
rules.sort_values(['support', 'confidence'], ascending=False)
# Out:
#                        antecedents   consequents  antecedent support  \
# 3  (fruit/vegetable juice, yogurt)  (whole milk)            0.017143
# 2                            (ham)  (whole milk)            0.022857
# 4          (margarine, rolls/buns)  (whole milk)            0.017143
# 7         (tropical fruit, yogurt)  (whole milk)            0.021429
# 1                 (frozen dessert)  (whole milk)            0.014286
# 0                        (cereals)  (whole milk)            0.011429
# 6       (root vegetables, sausage)  (rolls/buns)            0.012857
# 5        (other vegetables, sugar)  (whole milk)            0.014286
#
#    consequent support   support  confidence      lift  leverage  conviction
# 3            0.251429  0.014286    0.833333  3.314394  0.009976    4.491429
# 2            0.251429  0.014286    0.625000  2.485795  0.008539    1.996190
# 4            0.251429  0.012857    0.750000  2.982955  0.008547    2.994286
# 7            0.251429  0.012857    0.600000  2.386364  0.007469    1.871429
# 1            0.251429  0.011429    0.800000  3.181818  0.007837    3.742857
# 0            0.251429  0.010000    0.875000  3.480114  0.007127    5.988571
# 6            0.218571  0.010000    0.777778  3.558460  0.007190    3.516429
# 5            0.251429  0.010000    0.700000  2.784091  0.006408    2.495238
